# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('diamonds')

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %% [markdown]
# ### . Seperating categorical and continous columns

# %%
x,y=df.drop(columns=['price']),df['price']
xCat,xCont=x[['cut','color','clarity']],x.drop(columns=['cut','color','clarity'])

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
xTrain,xTest,yTrain,yTest = train_test_split(x,y,test_size=0.32,random_state=80)

# %%
x.select_dtypes(include=['object','bool','category'])
# Out:
#              cut color clarity
# 0          Ideal     E     SI2
# 1        Premium     E     SI1
# 2           Good     E     VS1
# 3        Premium     I     VS2
# 4           Good     J     SI2
# ...          ...   ...     ...
# 53935      Ideal     D     SI1
# 53936       Good     D     SI1
# 53937  Very Good     D     SI1
# 53938    Premium     H     SI2
# 53939      Ideal     D     SI2
#
# [53940 rows x 3 columns]

# %% [markdown]
# ### . Assigning nominal and ordinal columns

# %%
CatcolsNominal = ['color','clarity']
Catcolsordinal = ['cut']
Contcols= ['carat','depth','table','x','y','z']

# %%
import sklearn
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder,RobustScaler,PowerTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %% [markdown]
# ### . NominalPipeline

# %%
CatNominalPipeline = Pipeline(steps=[
    ('OneHotEncoding',OneHotEncoder(sparse_output=False,drop='first'))
])

# %%
df['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %% [markdown]
# ### . OrdinalPipeline

# %%
CatOrdinalPipeline = Pipeline(steps=[
    ('OrdinalEncoding',OrdinalEncoder(categories=[['Ideal','Premium','Very Good','Good','Fair']]))
])

# %% [markdown]
# ### . ContinousPipeline

# %%
ContPipeline = Pipeline(steps=[
    ('RobustScaler',RobustScaler()),
    ('yeojohnson',PowerTransformer())
])

# %% [markdown]
# ### . ColumnTransformer

# %%
preColTrans = ColumnTransformer(transformers = [
    ('catNominalPipeline',CatNominalPipeline,CatcolsNominal),
    ('catOrdinalPipeline',CatOrdinalPipeline,Catcolsordinal),
    ('contPipeline',ContPipeline,Contcols)
    
],remainder = 'passthrough')

# %% [markdown]
# ### .FinalPipeline

# %%
finalPipeline = Pipeline(steps = [
    ('preColTrans',preColTrans),
])

# %% [markdown]
# ### . Trainingdata

# %%
finalPipeline.fit_transform(xTrain)
# Out:
# array([[ 0.        ,  1.        ,  0.        , ..., -1.14405054,
#         -1.1378171 , -1.10583252],
#        [ 0.        ,  0.        ,  1.        , ..., -0.48102811,
#         -0.50367236, -0.42008106],
#        [ 0.        ,  0.        ,  0.        , ..., -1.22270703,
#         -1.20834094, -1.23283044],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., -0.91257274,
#         -0.88524668, -0.77137179],
#        [ 1.        ,  0.        ,  0.        , ..., -1.37071689,
#         -1.44836516, -1.45508817],
#        [ 0.        ,  0.        ,  0.        , ...,  0.91398641,
#          0.93231297,  0.89612174]])

# %% [markdown]
# ### .Trainingdata Dataframe

# %%
xTrainprocessed = pd.DataFrame(finalPipeline.fit_transform(xTrain),
                              columns=finalPipeline.get_feature_names_out(),
                              index = xTrain.index)

# %%
xTrainprocessed

# %%
finalPipeline.transform(xTest)
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  1.36621253,
#          1.28944448,  1.4265397 ],
#        [ 1.        ,  0.        ,  0.        , ..., -0.5218908 ,
#         -0.43046525, -0.40385856],
#        [ 0.        ,  0.        ,  0.        , ..., -0.54242539,
#         -0.51421704, -0.65206475],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  0.18641863,
#          0.23985943,  0.18982884],
#        [ 0.        ,  1.        ,  0.        , ..., -0.48102811,
#         -0.48264767, -0.37155579],
#        [ 0.        ,  0.        ,  0.        , ...,  0.69666697,
#          0.7379844 ,  0.65991089]])

# %% [markdown]
# ### . Testdata Dataframe

# %%
xTestprocessed = pd.DataFrame(finalPipeline.transform(xTest),
                              columns=finalPipeline.get_feature_names_out(),
                              index = xTest.index)

# %%
xTestprocessed
# Out:
#        catNominalPipeline__color_E  catNominalPipeline__color_F  \
# 21394                          0.0                          0.0
# 45561                          1.0                          0.0
# 46725                          0.0                          0.0
# 33918                          1.0                          0.0
# 40863                          0.0                          0.0
# ...                            ...                          ...
# 16638                          0.0                          0.0
# 37296                          0.0                          0.0
# 681                            0.0                          0.0
# 42830                          0.0                          1.0
# 9942                           0.0                          0.0
#
#        catNominalPipeline__color_G  catNominalPipeline__color_H  \
# 21394                          0.0                          0.0
# 45561                          0.0                          0.0
# 46725                          0.0                          0.0
# 33918                          0.0                          0.0
# 40863                          0.0                          0.0
# ...                            ...                          ...
# 16638                          1.0                          0.0
# 37296                          1.0                          0.0
# 681                            0.0                          0.0
# 42830                          0.0                          0.0
# 9942                           0.0                          1.0
#
#        catNominalPipeline__color_I  catNominalPipeline__color_J  \
# 21394                          1.0                          0.0
# 45561                          0.0                          0.0
# 46725                          0.0                          0.0
# 33918                          0.0                          0.0
# 40863                          1.0                          0.0
# ...                            ...                          ...
# 16638                          0.0                          0.0
# 37296                          0.0                          0.0
# 681                            0.0                          1.0
# 42830                          0.0                          0.0
# 9942                           0.0                          0.0
#
#        catNominalPipeline__clarity_IF  catNominalPipeline__clarity_SI1  \
# 21394                             0.0                              0.0
# 45561                             0.0                              0.0
# 46725                             0.0                              0.0
# 33918                             0.0                              0.0
# 40863                             0.0                              1.0
# ...                               ...                              ...
# 16638                             0.0                              0.0
# 37296                             0.0                              0.0
# 681                               0.0                              1.0
# 42830                             0.0                              1.0
# 9942                              0.0                              0.0
#
#        catNominalPipeline__clarity_SI2  catNominalPipeline__clarity_VS1  \
# 21394                              0.0                              1.0
# 45561                              0.0                              0.0
# 46725                              0.0                              1.0
# 33918                              0.0                              0.0
# 40863                              0.0                              0.0
# ...                                ...                              ...
# 16638                              0.0                              0.0
# 37296                              0.0                              0.0
# 681                                0.0                              0.0
# 42830                              0.0                              0.0
# 9942                               1.0                              0.0
#
#        catNominalPipeline__clarity_VS2  catNominalPipeline__clarity_VVS1  \
# 21394                              0.0                               0.0
# 45561                              1.0                               0.0
# 46725                              0.0                               0.0
# 33918                              1.0                               0.0
# 40863                              0.0                               0.0
# ...                                ...                               ...
# 16638                              1.0                               0.0
# 37296                              0.0                               1.0
# 681                                0.0                               0.0
# 42830                              0.0                               0.0
# 9942                               0.0                               0.0
#
#        catNominalPipeline__clarity_VVS2  catOrdinalPipeline__cut  \
# 21394                               0.0                      2.0
# 45561                               0.0                      0.0
# 46725                               0.0                      2.0
# 33918                               0.0                      1.0
# 40863                               0.0                      2.0
# ...                                 ...                      ...
# 16638                               0.0                      1.0
# 37296                               0.0                      0.0
# 681                                 0.0                      0.0
# 42830                               0.0                      2.0
# 9942                                0.0                      0.0
#
#        contPipeline__carat  contPipeline__depth  contPipeline__table  \
# 21394             1.398383             0.947348            -2.478706
# 45561            -0.497124             0.587806            -0.097095
# 46725            -0.671760            -1.206677             0.761274
# 33918            -1.345456             0.803079             0.355249
# 40863            -0.365084             0.021731            -0.611510
# ...                    ...                  ...                  ...
# 16638             0.852061            -1.072466             0.355249
# 37296            -0.973383             0.161997            -0.611510
# 681               0.169622            -0.186894            -0.611510
# 42830            -0.430252             0.875142             1.133835
# 9942              0.702269            -0.462204            -0.611510
#
#        contPipeline__x  contPipeline__y  contPipeline__z
# 21394         1.366213         1.289444         1.426540
# 45561        -0.521891        -0.430465        -0.403859
# 46725        -0.542425        -0.514217        -0.652065
# 33918        -1.416756        -1.509540        -1.343251
# 40863        -0.390106        -0.297364        -0.339444
# ...                ...              ...              ...
# 16638         0.936741         0.910353         0.785671
# 37296        -0.978012        -0.941808        -0.927899
# 681           0.186419         0.239859         0.189829
# 42830        -0.481028        -0.482648        -0.371556
# 9942          0.696667         0.737984         0.659911
#
# [17261 rows x 20 columns]

# %% [markdown]
# ### . Diagram representation

# %%
finalPipeline
# Out:
# Pipeline(steps=[('preColTrans',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('catNominalPipeline',
#                                                   Pipeline(steps=[('OneHotEncoding',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse_output=False))]),
#                                                   ['color', 'clarity']),
#                                                  ('catOrdinalPipeline',
#                                                   Pipeline(steps=[('OrdinalEncoding',
#                                                                    OrdinalEncoder(categories=[['Ideal',
#                                                                                                'Premium',
#                                                                                                'Very '
#                                                                                                'Good',
#                                                                                                'Good',
#                                                                                                'Fair']]))]),
#                                                   ['cut']),
#                                                  ('contPipeline',
#                                                   Pipeline(steps=[('RobustScaler',
#                                                                    RobustScaler()),
#                                                                   ('yeojohnson',
#                                                                    PowerTransformer())]),
#                                                   ['carat', 'depth', 'table',
#                                                    'x', 'y', 'z'])]))])
